# %% [markdown]
# <a href="https://colab.research.google.com/github/baimev3/NRPSims/blob/main/mumax3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mumax3 in google colaboratory**

# %% [markdown]
# # About Google colaboratory

# %% [markdown]
# Google colaboratory is a research tool mainly used by researchers in the field of machine learning. The main purpose of this tool is to run python code in jupyter notebooks. These notebooks run on a virtual linux machine private to your gmail account. This means that you will need a gmail account to execute programs in a google colaboratory session. If you have a gmail account you should be able to copy this jupyter notebook to your google drive and execute the code cells.
#
# To run mumax3 simulations, you do not need to write any python code. So you might wonder how we can use this jupyter notebook environment to run mumax3 simulations. The trick here is that you can execute shell commands by typing an exclamation mark followed by the command, as shown in the code cell below. If you run this code cell, the shell will print out the operating system of the virtual machine. Having the ability to run shell commands suffices to install and run mumax3 simulations, as demonstrated in the sections below.

# %%
! echo "This machine runs" $(uname)

# %% [markdown]
# # Installing mumax3

# %% [markdown]
# To install mumax3.10 on this virtual machine, you can run the cell below. This might take a few minutes. When the installation is done, you can collapse this section to get a clean workspace.

# %%
# Download the mumax3 binary
# !wget https://mumax.ugent.be/mumax3-binaries/mumax3.10_linux_cuda10.1.tar.gz
# !tar -xvf mumax3.10_linux_cuda10.1.tar.gz
# !rm mumax3.10_linux_cuda10.1.tar.gz
# !rm -rf mumax3.10 && mv mumax3.10_linux_cuda10.1 mumax3.10

#update the PATH environment variable
import os
os.environ['PATH'] += ":/content/mumax3.10"

# Download an examplary script
# !wget https://raw.githubusercontent.com/JeroenMulkers/mumax3-tutorial/master/standardproblem4.mx3 -O standardproblem4.mx3
# Out:
# --2026-01-06 15:29:37--  https://mumax.ugent.be/mumax3-binaries/mumax3.10_linux_cuda10.1.tar.gz
# Resolving mumax.ugent.be (mumax.ugent.be)... 157.193.40.77
# Connecting to mumax.ugent.be (mumax.ugent.be)|157.193.40.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150707207 (144M) [application/x-gzip]
# Saving to: ‘mumax3.10_linux_cuda10.1.tar.gz’
#
# mumax3.10_linux_cud 100%[===================>] 143.73M  22.0MB/s    in 7.4s
#
# 2026-01-06 15:29:45 (19.5 MB/s) - ‘mumax3.10_linux_cuda10.1.tar.gz’ saved [150707207/150707207]
#
# mumax3.10_linux_cuda10.1/
# mumax3.10_linux_cuda10.1/mumax3-server
# mumax3.10_linux_cuda10.1/lib/
# mumax3.10_linux_cuda10.1/lib/libcurand.so.10
# mumax3.10_linux_cuda10.1/lib/libcufft.so.10
# mumax3.10_linux_cuda10.1/mumax3
# mumax3.10_linux_cuda10.1/LICENSE
# mumax3.10_linux_cuda10.1/mumax3-convert
# --2026-01-06 15:29:48--  https://raw.githubusercontent.com/JeroenMulkers/mumax3-tutorial/master/standardproblem4.mx3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 258 [text/plain]
# Saving to: ‘standardproblem4.mx3’
#
# standardproblem4.mx 100%[===================>]     258  --.-KB/s    in 0s
#
# 2026-01-06 15:29:48 (9.04 MB/s) - ‘standardproblem4.mx3’ saved [258/258]

# %% [markdown]
# # Running a mumax3 script

# %% [markdown]
# You can open the filebrowser for this virtual machine on the left side of this page. Here you should see a mumax3 script named standardproblem4.mx3. You should be able to open this file with a double click. To execute the script run the code cell below.

# %%
# !mumax3 NRPSims24rev3e11.mx3
# Out:
# //mumax 3.10 [linux_amd64 go1.14(gc) CUDA-10.1]
# //GPU info: Tesla T4(15095MB), CUDA Driver 12.4, cc=7.5, using cc=75 PTX
# //(c) Arne Vansteenkiste, Dynamat LAB, Ghent University, Belgium
# //This is free software without any warranty. See license.txt
# //********************************************************************//
# //  If you use mumax in any work or publication,                      //
# //  we kindly ask you to cite the references in references.bib        //
# //********************************************************************//
# //output directory: NRPSims24rev3e11.out/
# //starting GUI at http://127.0.0.1:35367
# u := 1e-9
# Sx := 192
# Sy := 192
# SetGridsize(Sx, Sy, 1)
# SetCellsize(u, u, 1e-9)
# deg := pi / 180
# EdgeSmooth = 8
# Msat = 1e6
# Aex = 1.5e-11
# alpha = 0.012
# Ku1 = 1e6
# anisU = vector(0, 0, 1)
# Dind = 0.5e-3
# fixedlayer = vector(0, 1, 0)
# pol = 0.5
# epsilonPrime = 0
# setgeom(imageShape("NRPSims24rev.png"))
# // Initializing geometry 0 %
# // Initializing geometry 100 %
# save(geom)
# m = twodomain(0, 0, -1, 1, 0, 0, 0, 0, 1).transl(-u*76, 0, 0)
# saveas(m, "device")
# current := 3e11
# J.setregion(0, vector(0, 0, -current))
# autosave(m, 5e-11)
# tableautosave(1e-11)
# run(25e-10)
# //Using cached kernel: /tmp/mumax3kernel_[192 192 1]_[0 0 0]_[1e-09 1e-09 1e-09]_6_
# relax()
# //********************************************************************//
# //Please cite the following references, relevant for your simulation. //
# //See bibtex file in output folder for justification.                 //
# //********************************************************************//
# //   * Vansteenkiste et al., AIP Adv. 4, 107133 (2014).
# //   * Mulkers et al., Phys. Rev. B 95, 144401 (2017).

# %% [markdown]
# If you ran the cell above, then there should be a directory named standardproblem4.out (you might need to click on the refresh button in the filebrowser). This directory contains the output files of the simulation. mumax3-convert can now be used to convert the ovf files to images, as demonstrated in the cell below.

# %%
# !mumax3-convert -png NRPSims24rev3e11.out/*.ovf
# Out:
# NRPSims24rev3e11.out/device.ovf
# NRPSims24rev3e11.out/geom000000.ovf
# NRPSims24rev3e11.out/m000000.ovf
# NRPSims24rev3e11.out/m000001.ovf
# NRPSims24rev3e11.out/m000002.ovf
# NRPSims24rev3e11.out/m000003.ovf
# NRPSims24rev3e11.out/m000004.ovf
# NRPSims24rev3e11.out/m000005.ovf
# NRPSims24rev3e11.out/m000006.ovf
# NRPSims24rev3e11.out/m000007.ovf
# NRPSims24rev3e11.out/m000008.ovf
# NRPSims24rev3e11.out/m000009.ovf
# NRPSims24rev3e11.out/m000010.ovf
# NRPSims24rev3e11.out/m000011.ovf
# NRPSims24rev3e11.out/m000012.ovf
# NRPSims24rev3e11.out/m000013.ovf
# NRPSims24rev3e11.out/m000014.ovf
# NRPSims24rev3e11.out/m000015.ovf
# NRPSims24rev3e11.out/m000016.ovf
# NRPSims24rev3e11.out/m000017.ovf
# [ ok ] NRPSims24rev3e11.out/m000044.ovf	-> NRPSims24rev3e11.out/m000044.png
# [ ok ] NRPSims24rev3e11.out/m000046.ovf	-> NRPSims24rev3e11.out/m000046.png
# [ ok ] NRPSims24rev3e11.out/m000045.ovf	-> NRPSims24rev3e11.out/m000045.png
# [ ok ] NRPSims24rev3e11.out/m000043.ovf	-> NRPSims24rev3e11.out/m000043.png
# [ ok ] NRPSims24rev3e11.out/m000049.ovf	-> NRPSims24rev3e11.out/m000049.png
# [ ok ] NRPSims24rev3e11.out/m000047.ovf	-> NRPSims24rev3e11.out/m000047.png
# [ ok ] NRPSims24rev3e11.out/m000048.ovf	-> NRPSims24rev3e11.out/m000048.png
# [ ok ] NRPSims24rev3e11.out/m000050.ovf	-> NRPSims24rev3e11.out/m000050.png
# 53 files converted,  0 skipped,  0 failed

# %% [markdown]
# Now it's up to you. Right click on the filebrowser to add a new file. Open the file and write your first mumax3 script. Run this script as demonstrated above.

# %%
# !zip -r /content/NRPSims24rev3e11.zip /content/NRPSims24rev3e11.out
# Out:
#   adding: content/NRPSims24rev3e11.out/ (stored 0%)
#   adding: content/NRPSims24rev3e11.out/m000007.png (deflated 9%)
#   adding: content/NRPSims24rev3e11.out/m000004.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000013.png (deflated 9%)
#   adding: content/NRPSims24rev3e11.out/m000045.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000023.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000013.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000011.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000047.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000015.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000003.png (deflated 6%)
#   adding: content/NRPSims24rev3e11.out/m000000.ovf (deflated 99%)
#   adding: content/NRPSims24rev3e11.out/m000025.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000011.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000030.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000044.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000023.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000017.png (deflated 9%)
#   adding: content/NRPSims24rev3e11.out/m000043.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000033.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000048.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000039.png (deflated 9%)
#   adding: content/NRPSims24rev3e11.out/m000050.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000005.png (deflated 7%)
#   adding: content/NRPSims24rev3e11.out/m000021.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000020.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000050.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000031.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000021.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000038.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000027.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000008.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/device.png (deflated 17%)
#   adding: content/NRPSims24rev3e11.out/m000043.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000002.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000009.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000037.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000047.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000027.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000026.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000007.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000024.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000044.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000014.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000045.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000006.png (deflated 8%)
#   adding: content/NRPSims24rev3e11.out/m000040.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000020.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000022.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000041.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000042.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000014.png (deflated 9%)
#   adding: content/NRPSims24rev3e11.out/m000010.png (deflated 9%)
#   adding: content/NRPSims24rev3e11.out/m000033.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/references.bib (deflated 58%)
#   adding: content/NRPSims24rev3e11.out/m000022.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000042.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000029.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000030.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000024.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000028.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000031.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000016.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000001.png (deflated 7%)
#   adding: content/NRPSims24rev3e11.out/m000032.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000003.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000012.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000004.png (deflated 7%)
#   adding: content/NRPSims24rev3e11.out/m000041.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/geom000000.ovf (deflated 99%)
#   adding: content/NRPSims24rev3e11.out/m000005.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000019.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000035.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000018.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000040.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000008.png (deflated 8%)
#   adding: content/NRPSims24rev3e11.out/m000028.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000032.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000039.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000017.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000034.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000046.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000036.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000026.png (deflated 11%)
#   adding: content/NRPSims24rev3e11.out/m000025.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000029.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000015.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000001.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000012.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000037.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/gui (stored 0%)
#   adding: content/NRPSims24rev3e11.out/m000016.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000049.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/table.txt (deflated 57%)
#   adding: content/NRPSims24rev3e11.out/m000049.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000010.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000038.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000009.png (deflated 8%)
#   adding: content/NRPSims24rev3e11.out/m000006.ovf (deflated 86%)
#   adding: content/NRPSims24rev3e11.out/m000035.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000048.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000046.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000000.png (deflated 17%)
#   adding: content/NRPSims24rev3e11.out/geom000000.png (deflated 14%)
#   adding: content/NRPSims24rev3e11.out/m000018.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/log.txt (deflated 51%)
#   adding: content/NRPSims24rev3e11.out/m000036.ovf (deflated 87%)
#   adding: content/NRPSims24rev3e11.out/m000019.png (deflated 9%)
#   adding: content/NRPSims24rev3e11.out/device.ovf (deflated 99%)
#   adding: content/NRPSims24rev3e11.out/m000034.png (deflated 10%)
#   adding: content/NRPSims24rev3e11.out/m000002.png (deflated 6%)
